# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.uniform(-3, 3, size=100)
X= x.reshape(-1, 1)
y = 0.5 * x  + 3 + np.random.normal(0, 1, size=100)

# %%
plt.scatter(x,y)
plt.show()

# %%
from sklearn.model_selection import train_test_split
np.random.seed(666)
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

def PolynomialRegression(degree):
  print("PolynomialRegression:",  degree)
  return Pipeline([
  ('poly', PolynomialFeatures(degree=degree)),
  ('std_scaler', StandardScaler()),
  ('lin_reg', LinearRegression())
])

# %%
from sklearn.metrics import mean_squared_error
poly_reg = PolynomialRegression(degree=20)
poly_reg.fit(X_train, y_train)
y_poly_predict = poly_reg.predict(X_test)
mean_squared_error(y_test, y_poly_predict)
# Out:
# PolynomialRegression: 20
# 3.4032066077123293

# %%
X_plot = np.linspace(-3, 3, 100).reshape(-1, 1)
y_plot = poly_reg.predict(X_plot)
# y2_plot = poly2_reg.predict(X_plot)
plt.scatter(X, y)
plt.plot(X_plot[:,0], y_plot, color = 'r')
# plt.plot(X_plot[:,0], y2_plot, color = 'g')?
plt.axis([-3, 3, 0, 10])
plt.show()

# %%
def plot_model(model):
  X_plot = np.linspace(-3, 3, 100).reshape(-1, 1)
  y_plot = model.predict(X_plot)
# y2_plot = poly2_reg.predict(X_plot)
  plt.scatter(X, y)
  plt.plot(X_plot[:,0], y_plot, color = 'r')
# plt.plot(X_plot[:,0], y2_plot, color = 'g')?
  plt.axis([-3, 3, 0, 10])
  plt.show()

# %%
plot_model(poly_reg)

# %% [markdown]
# ### 使用岭回归

# %%
from sklearn.linear_model import Ridge

def RidgeRegression(degree, alpha):
  print("PolynomialRegression:",  degree)
  return Pipeline([
  ('poly', PolynomialFeatures(degree=degree)),
  ('std_scaler', StandardScaler()),
  ('ridge_reg', Ridge(alpha=alpha))
])

ridge1_reg = RidgeRegression(20, 10)
ridge1_reg.fit(X_train, y_train)
plot_model(ridge1_reg)
# Out:
# PolynomialRegression: 20

# %% [markdown]
# ### lasso

# %%
from sklearn.linear_model import Lasso

def LassoRegression(degree, alpha):
  # print("PolynomialRegression:",  degree)
  return Pipeline([
  ('poly', PolynomialFeatures(degree=degree)),
  ('std_scaler', StandardScaler()),
  ('lasso_reg', Lasso(alpha=alpha))
])

lasso1_reg = LassoRegression(20, 1)
lasso1_reg.fit(X_train, y_train)
y_predict = lasso1_reg.predict(X_test)
mean_squared_error(y_test, y_predict)
# plot_model(lasso1_reg)
# Out:
# 2.057075355057784

# %%
lasso1_reg.get_params()
# Out:
# {'memory': None,
#  'steps': [('poly', PolynomialFeatures(degree=20)),
#   ('std_scaler', StandardScaler()),
#   ('lasso_reg', Lasso(alpha=1))],
#  'verbose': False,
#  'poly': PolynomialFeatures(degree=20),
#  'std_scaler': StandardScaler(),
#  'lasso_reg': Lasso(alpha=1),
#  'poly__degree': 20,
#  'poly__include_bias': True,
#  'poly__interaction_only': False,
#  'poly__order': 'C',
#  'std_scaler__copy': True,
#  'std_scaler__with_mean': True,
#  'std_scaler__with_std': True,
#  'lasso_reg__alpha': 1,
#  'lasso_reg__copy_X': True,
#  'lasso_reg__fit_intercept': True,
#  'lasso_reg__max_iter': 1000,
#  'lasso_reg__positive': False,
#  'lasso_reg__precompute': False,
#  'lasso_reg__random_state': None,
#  'lasso_reg__selection': 'cyclic',
#  'lasso_reg__tol': 0.0001,
#  'lasso_reg__warm_start': False}

# %%
from sklearn.linear_model import E
def LassoRegression(degree, alpha):
  # print("PolynomialRegression:",  degree)
  return Pipeline([
  ('poly', PolynomialFeatures(degree=degree)),
  ('std_scaler', StandardScaler()),
  ('lasso_reg', Lasso(alpha=alpha))
])
