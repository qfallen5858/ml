# %% [markdown]
# ### 获得前n个主成分

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.empty((100, 2))
X[:,0] = np.random.uniform(0., 100., size = 100)
X[:,1] = 0.75 * X[:,0] + 3. + np.random.normal(0., 10., size = 100)

# %%
plt.scatter(X[:,0],X[:,1] )
plt.show()

# %%
def demean(X):
  return X- np.mean(X, axis=0)

X = demean(X)

def f(w, X):
  return  np.sum((X.dot(w))**2) / len(X)

def df(w, X):
  return X.T.dot(X.dot(w)) * 2. / len(X)

def direction(w):
  return w / np.linalg.norm(w)

def first_component(X, initial_w, eta, n_iters = 1e4, epsilon=1e-8):
  cur_iter = 0
  w = direction(initial_w)
  while cur_iter < n_iters:
    gradient = df(w, X)
    last_w = w
    w = w + eta * gradient
    w = direction(w) # 注意1：每次求一个单位方向
    if abs(f(w,X) - f(last_w, X)) < epsilon:
      break
    
    cur_iter += 1
  
  return w

# %%
initial_w = np.random.random(X.shape[1])
eta = 0.01
w = first_component(X, initial_w, eta)

# %%
w
# Out:
# array([0.78512697, 0.61933484])

# %%
X2 = np.empty(X.shape)
# for i in range(len(X)):
#   X2[i] = X[i] - X[i].dot(w) * w
X2 = X - X - X.dot(w).reshape(-1, 1)* w

# %%
plt.scatter(X2[:,0], X2[:,1])
plt.show()

# %%
w2 = first_component(X2, initial_w, eta)

# %%
w2
# Out:
# array([0.78512697, 0.61933484])

# %%
w.dot(w2)
# Out:
# 1.0

# %%
def first_n_components(n, X, eta=0.01, n_iters = 1e4, epsilon=1e-8):
  
  X_pca = X.copy()
  X_pca = demean(X_pca)
  res = []
  for i in range(n):
    initial_w = np.random.random(X_pca.shape[1])
    w = first_n_components(X_pca, initial_w, eta)
    res.append(w)
     
    X_pca = X_pca - X_pca.dot(w).reshape(-1, 1)*2
  
  return res

# %%
X = np.empty((100, 2))
X[:,0] = np.random.uniform(0., 100., size = 100)
X[:,1] = 0.75 * X[:,0] + 3. + np.random.normal(0., 10., size = 100)
first_n_components(2,X)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       2 X[:,0] = np.random.uniform(0., 100., size = 100)
#       3 X[:,1] = 0.75 * X[:,0] + 3. + np.random.normal(0., 10., size = 100)
# ----> 4 first_n_components(2,X)
#
# Cell In[17], line 8, in first_n_components(n, X, eta, n_iters, epsilon)
#       6 for i in range(n):
#       7   initial_w = np.random.random(X_pca.shape[1])
# ----> 8   w = first_n_components(X_pca, initial_w, eta)
#       9   res.append(w)
#      11   X_pca = X_pca - X_pca.dot(w).reshape(-1, 1)*2
#
# Cell In[17], line 6, in first_n_components(n, X, eta, n_iters, epsilon)
#       4 X_pca = demean(X_pca)
#       5 res = []
# ----> 6 for i in range(n):
#       7   initial_w = np.random.random(X_pca.shape[1])
#       8   w = first_n_components(X_pca, initial_w, eta)
#
# TypeError: only integer scalar arrays can be converted to a scalar index
